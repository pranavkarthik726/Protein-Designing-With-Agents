# %%
import pyrosetta

# Initialize PyRosetta (use default options)
pyrosetta.init()

# Load the PDB file into a pose
pose = pyrosetta.pose_from_pdb("1ubq.pdb")
print(f"Loaded structure with {pose.total_residue()} residues.")
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python312.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python312.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=1374690032 seed_offset=0 real_seed=1374690032
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=1374690032 RG_type=mt19937
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 985 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 4.36662 seconds.
# core.import_pose.import_pose: File '1ubq.pdb' automatically determined to be of type PDB from contents.
# Loaded structure with 76 residues.

# %%
# Get the default full-atom score function
scorefxn = pyrosetta.get_fa_scorefxn()

# Score the original structure
initial_score = scorefxn(pose)
print(f"Initial Total Score: {initial_score:.3f} REU")
# Out:
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.etable: Starting energy table calculation
# core.scoring.etable: smooth_etable: changing atr/rep split to bottom of energy well
# core.scoring.etable: smooth_etable: spline smoothing lj etables (maxdis = 6)
# core.scoring.etable: smooth_etable: spline smoothing solvation etables (max_dis = 6)
# core.scoring.etable: Finished calculating energy tables.
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/prepro.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA_n
# core.scoring.P_AA: shapovalov_lib::shap_p_aa_pp_smooth_level of 1( aka low_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/shapovalov/10deg/kappa131/a20.prop
# basic.io.database: Database file opened: scoring/score_functions/elec_cp_reps.dat
# core.scoring.elec.util: Read 40 countpair representative atoms
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib_fixes_enable option is true.
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib::shap_dun10_smooth_level of 1( aka lowest_smooth ) got activated.
# core.pack.dunbrack.RotamerLibrary: Binary rotamer library selected: /root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin
# core.pack.dunbrack.RotamerLibrary: Using Dunbrack library binary file '/root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin'.
# core.pack.dunbrack.RotamerLibrary: Dunbrack 2010 library took 3.82667 seconds to load from binary
# Initial Total Score: 32.678 REU

# %%
from pyrosetta.rosetta.protocols.relax import FastRelax
from pyrosetta.rosetta.core.pack.task import TaskFactory
from pyrosetta.rosetta.core.pack.task.operation import RestrictToRepacking

# Set up the FastRelax protocol
fast_relax = FastRelax()
fast_relax.set_scorefxn(scorefxn)

# Optionally, you can set additional parameters if needed
# fast_relax.max_iter(200)

# Run the relax protocol on a copy of the pose
import copy
pose_relaxed = pyrosetta.Pose()
pose_relaxed.assign(pose)  # make a copy

fast_relax.apply(pose_relaxed)
print("Relaxation complete.")
# Out:
# protocols.relax.RelaxScriptManager: Reading relax scripts list from database.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# protocols.relax.RelaxScriptManager: Looking for MonomerRelax2019.txt
# protocols.relax.RelaxScriptManager: ================== Reading script file: /root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.txt ==================
# protocols.relax.RelaxScriptManager: repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 1
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: min 0.00001
# protocols.relax.RelaxScriptManager: accept_to_best
# protocols.relax.RelaxScriptManager: endrepeat
# protocols.relax.FastRelax: CMD: repeat  32.6778  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  32.6778  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -22.0796  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1762 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -245.208  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -243.384  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -323.391  1.32382  1.32382  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -323.391  1.32382  1.32382  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -213.338  1.32382  1.32382  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1626 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -229.323  1.32382  1.32382  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -223.152  1.32382  1.32382  0.154
# protocols.relax.FastRelax: CMD: min  -274.591  1.06047  1.06047  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -274.591  1.06047  1.06047  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -237.807  1.06047  1.06047  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1508 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -237.665  1.06047  1.06047  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -234.863  1.06047  1.06047  0.31955
# protocols.relax.FastRelax: CMD: min  -256.795  0.746634  0.746634  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -256.795  0.746634  0.746634  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -228.956  0.746634  0.746634  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1484 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -229.813  0.746634  0.746634  0.55
# protocols.relax.FastRelax: CMD: min  -255.425  0.822594  0.822594  0.55
# protocols.relax.FastRelax: MRP: 0  -255.425  -255.425  0.822594  0.822594
# protocols.relax.FastRelax: CMD: accept_to_best  -255.425  0.822594  0.822594  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -255.425  0.822594  0.822594  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -255.425  0.822594  0.822594  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -299.044  0.822594  0.822594  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1829 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -302.476  0.822594  0.822594  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -301.369  0.822594  0.822594  0.02805
# protocols.relax.FastRelax: CMD: min  -345.598  1.4312  1.4312  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -345.598  1.4312  1.4312  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -253.136  1.4312  1.4312  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1676 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -255.798  1.4312  1.4312  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -249.822  1.4312  1.4312  0.154
# protocols.relax.FastRelax: CMD: min  -300.558  1.10948  1.10948  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -300.558  1.10948  1.10948  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -268.401  1.10948  1.10948  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1625 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -268.645  1.10948  1.10948  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -266.102  1.10948  1.10948  0.31955
# protocols.relax.FastRelax: CMD: min  -274.506  1.01246  1.01246  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -274.506  1.01246  1.01246  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -243.033  1.01246  1.01246  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1532 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -243.068  1.01246  1.01246  0.55
# protocols.relax.FastRelax: CMD: min  -257.324  0.866256  0.866256  0.55
# protocols.relax.FastRelax: MRP: 1  -257.324  -257.324  0.866256  0.866256
# protocols.relax.FastRelax: CMD: accept_to_best  -257.324  0.866256  0.866256  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -257.324  0.866256  0.866256  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -257.324  0.866256  0.866256  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -301.159  0.866256  0.866256  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1793 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -303.423  0.866256  0.866256  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -302.453  0.866256  0.866256  0.02805
# protocols.relax.FastRelax: CMD: min  -346.132  1.57129  1.57129  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -346.132  1.57129  1.57129  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -252.869  1.57129  1.57129  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1689 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -255.601  1.57129  1.57129  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -249.39  1.57129  1.57129  0.154
# protocols.relax.FastRelax: CMD: min  -302.09  1.25855  1.25855  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -302.09  1.25855  1.25855  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -268.606  1.25855  1.25855  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1681 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -268.911  1.25855  1.25855  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -266.275  1.25855  1.25855  0.31955
# protocols.relax.FastRelax: CMD: min  -275.882  1.1763  1.1763  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -275.882  1.1763  1.1763  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -243.742  1.1763  1.1763  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1588 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -243.937  1.1763  1.1763  0.55
# protocols.relax.FastRelax: CMD: min  -258.038  0.889251  0.889251  0.55
# protocols.relax.FastRelax: MRP: 2  -258.038  -258.038  0.889251  0.889251
# protocols.relax.FastRelax: CMD: accept_to_best  -258.038  0.889251  0.889251  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -258.038  0.889251  0.889251  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -258.038  0.889251  0.889251  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -302.268  0.889251  0.889251  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1784 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -304.696  0.889251  0.889251  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -303.826  0.889251  0.889251  0.02805
# protocols.relax.FastRelax: CMD: min  -342.501  1.39554  1.39554  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -342.501  1.39554  1.39554  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -263.104  1.39554  1.39554  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1708 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -267.319  1.39554  1.39554  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -262.152  1.39554  1.39554  0.154
# protocols.relax.FastRelax: CMD: min  -300.854  1.17995  1.17995  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -300.854  1.17995  1.17995  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -267.193  1.17995  1.17995  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1616 rotamers at 76 positions.

# %%
relaxed_score = scorefxn(pose_relaxed)
print(f"Relaxed Total Score: {relaxed_score:.3f} REU")
# Out:
# Relaxed Total Score: -259.970 REU

# %%
print("Per-residue energies:")
for i in range(1, pose_relaxed.total_residue() + 1):
    residue_energy = pose_relaxed.energies().residue_total_energy(i)
    print(f"Residue {i}: {residue_energy:.3f} REU")
# Out:
# Per-residue energies:
# Residue 1: -2.615 REU
# Residue 2: -2.578 REU
# Residue 3: -6.916 REU
# Residue 4: -3.319 REU
# Residue 5: -5.684 REU
# Residue 6: -3.158 REU
# Residue 7: -3.962 REU
# Residue 8: 0.354 REU
# Residue 9: -0.255 REU
# Residue 10: -1.717 REU
# Residue 11: -4.488 REU
# Residue 12: -1.427 REU
# Residue 13: -3.160 REU
# Residue 14: -2.260 REU
# Residue 15: -5.099 REU
# Residue 16: -2.399 REU
# Residue 17: -3.695 REU
# Residue 18: -1.022 REU
# Residue 19: -4.832 REU
# Residue 20: -1.367 REU
# Residue 21: -5.815 REU
# Residue 22: -2.475 REU
# Residue 23: -3.575 REU
# Residue 24: -1.768 REU
# Residue 25: -1.761 REU
# Residue 26: -3.644 REU
# Residue 27: -7.249 REU
# Residue 28: -1.708 REU
# Residue 29: -4.355 REU
# Residue 30: -6.439 REU
# Residue 31: -0.881 REU
# Residue 32: -0.174 REU
# Residue 33: 0.137 REU
# Residue 34: -2.705 REU
# Residue 35: -1.953 REU
# Residue 36: -3.375 REU
# Residue 37: -4.271 REU
# Residue 38: -4.004 REU
# Residue 39: -1.831 REU
# Residue 40: -3.621 REU
# Residue 41: -4.735 REU
# Residue 42: -0.840 REU
# Residue 43: -6.019 REU
# Residue 44: -3.916 REU
# Residue 45: -2.343 REU
# Residue 46: 1.355 REU
# Residue 47: -1.511 REU
# Residue 48: -2.238 REU
# Residue 49: -1.043 REU
# Residue 50: -5.066 REU
# Residue 51: -3.256 REU
# Residue 52: -3.578 REU
# Residue 53: 0.900 REU
# Residue 54: -2.283 REU
# Residue 55: -3.955 REU
# Residue 56: -6.580 REU
# Residue 57: -1.889 REU
# Residue 58: -3.820 REU
# Residue 59: -4.306 REU
# Residue 60: -2.793 REU
# Residue 61: -5.289 REU
# Residue 62: -2.383 REU
# Residue 63: -0.229 REU
# Residue 64: -0.354 REU
# Residue 65: -3.014 REU
# Residue 66: -1.592 REU
# Residue 67: -7.453 REU
# Residue 68: -1.170 REU
# Residue 69: -5.951 REU
# Residue 70: -2.620 REU
# Residue 71: -4.211 REU
# Residue 72: 0.200 REU
# Residue 73: -0.530 REU
# Residue 74: 0.670 REU
# Residue 75: -1.183 REU
# Residue 76: 0.646 REU

# %%
import pyrosetta
from pyrosetta.rosetta.protocols.relax import FastRelax

def initialize_pyrosetta(extra_flags=""):
    """
    Initialize PyRosetta with optional extra flags.
    """
    pyrosetta.init(extra_flags)
    print("PyRosetta initialized.")

def load_protein(pdb_file):
    """
    Load a protein structure from a PDB file into a PyRosetta pose.
    """
    try:
        pose = pyrosetta.pose_from_pdb(pdb_file)
        print(f"Loaded structure from {pdb_file} with {pose.total_residue()} residues.")
        return pose
    except Exception as e:
        print(f"Error loading PDB file {pdb_file}: {e}")
        return None

def score_protein(pose, scorefxn=None):
    """
    Score the given pose using a full-atom score function.
    If no scorefxn is provided, the default full-atom score function is used.
    Returns the total score (REU).
    """
    if scorefxn is None:
        scorefxn = pyrosetta.get_fa_scorefxn()
    total_score = scorefxn(pose)
    print(f"Total Score: {total_score:.3f} REU")
    return total_score, scorefxn

def relax_structure(pose, scorefxn, nstruct=1):
    """
    Apply the FastRelax protocol to the structure.
    Returns the relaxed pose.
    """
    # Create a copy of the pose to relax
    relaxed_pose = pyrosetta.Pose()
    relaxed_pose.assign(pose)
    
    fast_relax = FastRelax()
    fast_relax.set_scorefxn(scorefxn)
    
    # Apply relaxation nstruct times (for multiple models, if desired)
    for i in range(nstruct):
        fast_relax.apply(relaxed_pose)
    print("Relaxation complete.")
    return relaxed_pose

def print_per_residue_energies(pose):
    """
    Print the per-residue energies for the given pose.
    """
    print("Per-residue energies:")
    # Access the energies from the pose object
    energies = pose.energies()
    for i in range(1, pose.total_residue() + 1):
        energy = energies.residue_total_energy(i)
        print(f"Residue {i}: {energy:.3f} REU")

# -------------------------------
# Example workflow
# -------------------------------
if __name__ == "__main__":
    # Initialize PyRosetta
    initialize_pyrosetta("-ex1 -ex2aro")
    
    # Load protein structure (update path as needed)
    pdb_file = "1ubq.pdb"
    pose = load_protein(pdb_file)
    if pose is None:
        raise SystemExit("Failed to load PDB file.")
    
    # Score the original structure
    initial_score, scorefxn = score_protein(pose)
    
    # Relax the structure
    pose_relaxed = relax_structure(pose, scorefxn)
    
    # Re-score the relaxed structure
    relaxed_score, _ = score_protein(pose_relaxed)
    
    # Print per-residue energies
    print_per_residue_energies(pose_relaxed)
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python312.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python312.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=89632231 seed_offset=0 real_seed=89632231
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=89632231 RG_type=mt19937
# PyRosetta initialized.
# core.import_pose.import_pose: File '1ubq.pdb' automatically determined to be of type PDB from contents.
# Loaded structure from 1ubq.pdb with 76 residues.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Total Score: 32.678 REU
# protocols.relax.RelaxScriptManager: Reading relax scripts list from database.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# protocols.relax.RelaxScriptManager: Looking for MonomerRelax2019.txt
# protocols.relax.RelaxScriptManager: ================== Reading script file: /root/pyrosetta_env/venv/lib/python3.12/site-packages/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.txt ==================
# protocols.relax.RelaxScriptManager: repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 1
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: min 0.00001
# protocols.relax.RelaxScriptManager: accept_to_best
# protocols.relax.RelaxScriptManager: endrepeat
# protocols.relax.FastRelax: CMD: repeat  32.6778  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  32.6778  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -22.0796  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1762 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -245.278  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -243.454  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -324.571  1.25964  1.25964  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -324.571  1.25964  1.25964  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -213.725  1.25964  1.25964  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1652 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -231.25  1.25964  1.25964  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -224.901  1.25964  1.25964  0.154
# protocols.relax.FastRelax: CMD: min  -275.106  1.024  1.024  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -275.106  1.024  1.024  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -235.597  1.024  1.024  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1527 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -231.18  1.024  1.024  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -228.128  1.024  1.024  0.31955
# protocols.relax.FastRelax: CMD: min  -239.7  0.95719  0.95719  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -239.7  0.95719  0.95719  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -202.403  0.95719  0.95719  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1510 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -208.627  0.95719  0.95719  0.55
# protocols.relax.FastRelax: CMD: min  -256.73  0.993647  0.993647  0.55
# protocols.relax.FastRelax: MRP: 0  -256.73  -256.73  0.993647  0.993647
# protocols.relax.FastRelax: CMD: accept_to_best  -256.73  0.993647  0.993647  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -256.73  0.993647  0.993647  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -256.73  0.993647  0.993647  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -299.919  0.993647  0.993647  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1743 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -304.843  0.993647  0.993647  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -303.999  0.993647  0.993647  0.02805
# protocols.relax.FastRelax: CMD: min  -345.82  1.48284  1.48284  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -345.82  1.48284  1.48284  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -256.572  1.48284  1.48284  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1727 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -260.091  1.48284  1.48284  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -254.158  1.48284  1.48284  0.154
# protocols.relax.FastRelax: CMD: min  -303.553  1.23328  1.23328  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -303.553  1.23328  1.23328  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -272.202  1.23328  1.23328  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1595 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -272.667  1.23328  1.23328  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -270.223  1.23328  1.23328  0.31955
# protocols.relax.FastRelax: CMD: min  -277.617  1.15014  1.15014  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -277.617  1.15014  1.15014  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -246.397  1.15014  1.15014  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1501 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -246.55  1.15014  1.15014  0.55
# protocols.relax.FastRelax: CMD: min  -258.836  1.01817  1.01817  0.55
# protocols.relax.FastRelax: MRP: 1  -258.836  -258.836  1.01817  1.01817
# protocols.relax.FastRelax: CMD: accept_to_best  -258.836  1.01817  1.01817  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -258.836  1.01817  1.01817  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -258.836  1.01817  1.01817  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -302.554  1.01817  1.01817  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1742 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -305.027  1.01817  1.01817  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -304.258  1.01817  1.01817  0.02805
# protocols.relax.FastRelax: CMD: min  -342.013  1.42905  1.42905  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -342.013  1.42905  1.42905  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -256.718  1.42905  1.42905  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1665 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -261.708  1.42905  1.42905  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -256.356  1.42905  1.42905  0.154
# protocols.relax.FastRelax: CMD: min  -301.195  1.29578  1.29578  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -301.195  1.29578  1.29578  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -270.549  1.29578  1.29578  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1597 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -270.868  1.29578  1.29578  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -268.455  1.29578  1.29578  0.31955
# protocols.relax.FastRelax: CMD: min  -275.341  1.2425  1.2425  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -275.341  1.2425  1.2425  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -243.95  1.2425  1.2425  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1508 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -244.101  1.2425  1.2425  0.55
# protocols.relax.FastRelax: CMD: min  -260.974  1.19564  1.19564  0.55
# protocols.relax.FastRelax: MRP: 2  -260.974  -260.974  1.19564  1.19564
# protocols.relax.FastRelax: CMD: accept_to_best  -260.974  1.19564  1.19564  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -260.974  1.19564  1.19564  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -260.974  1.19564  1.19564  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -305.199  1.19564  1.19564  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1807 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -308.473  1.19564  1.19564  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -307.427  1.19564  1.19564  0.02805
# protocols.relax.FastRelax: CMD: min  -344.81  1.52968  1.52968  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -344.81  1.52968  1.52968  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -262.133  1.52968  1.52968  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1748 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -270.765  1.52968  1.52968  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -265.658  1.52968  1.52968  0.154
# protocols.relax.FastRelax: CMD: min  -304.026  1.38297  1.38297  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -304.026  1.38297  1.38297  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -271.5  1.38297  1.38297  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1568 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -272.245  1.38297  1.38297  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -269.676  1.38297  1.38297  0.31955
# protocols.relax.FastRelax: CMD: min  -279.299  1.32802  1.32802  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -279.299  1.32802  1.32802  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -247.136  1.32802  1.32802  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1522 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -247.233  1.32802  1.32802  0.55
# protocols.relax.FastRelax: CMD: min  -261.273  1.17027  1.17027  0.55
# protocols.relax.FastRelax: MRP: 3  -261.273  -261.273  1.17027  1.17027
# protocols.relax.FastRelax: CMD: accept_to_best  -261.273  1.17027  1.17027  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -261.273  1.17027  1.17027  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -261.273  1.17027  1.17027  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -304.984  1.17027  1.17027  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1756 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -309.602  1.17027  1.17027  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -308.652  1.17027  1.17027  0.02805
# protocols.relax.FastRelax: CMD: min  -338.932  1.43918  1.43918  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -338.932  1.43918  1.43918  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -271.411  1.43918  1.43918  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1646 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -281.246  1.43918  1.43918  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -277.409  1.43918  1.43918  0.154
# protocols.relax.FastRelax: CMD: min  -304.527  1.35792  1.35792  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -304.527  1.35792  1.35792  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -274.695  1.35792  1.35792  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1561 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -275.442  1.35792  1.35792  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -273.094  1.35792  1.35792  0.31955
# protocols.relax.FastRelax: CMD: min  -280.606  1.28959  1.28959  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -280.606  1.28959  1.28959  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -250.678  1.28959  1.28959  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1480 rotamers at 76 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -250.888  1.28959  1.28959  0.55
# protocols.relax.FastRelax: CMD: min  -261.15  1.18494  1.18494  0.55
# protocols.relax.FastRelax: MRP: 4  -261.15  -261.273  1.17027  1.17027
# protocols.relax.FastRelax: CMD: accept_to_best  -261.15  1.18494  1.18494  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -261.15  1.18494  1.18494  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# Relaxation complete.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Total Score: -261.273 REU
# Per-residue energies:
# Residue 1: -2.495 REU
# Residue 2: -2.757 REU
# Residue 3: -6.892 REU
# Residue 4: -3.343 REU
# Residue 5: -5.677 REU
# Residue 6: -3.148 REU
# Residue 7: -3.574 REU
# Residue 8: 0.076 REU
# Residue 9: -0.169 REU
# Residue 10: -1.898 REU
# Residue 11: -4.459 REU
# Residue 12: -1.414 REU
# Residue 13: -3.073 REU
# Residue 14: -3.442 REU
# Residue 15: -5.062 REU
# Residue 16: -2.299 REU
# Residue 17: -3.725 REU
# Residue 18: -1.031 REU
# Residue 19: -4.820 REU
# Residue 20: -1.359 REU
# Residue 21: -5.733 REU
# Residue 22: -2.431 REU
# Residue 23: -3.682 REU
# Residue 24: -1.774 REU
# Residue 25: -1.795 REU
# Residue 26: -3.714 REU
# Residue 27: -7.449 REU
# Residue 28: -0.723 REU
# Residue 29: -4.305 REU
# Residue 30: -6.101 REU
# Residue 31: -1.633 REU
# Residue 32: -0.172 REU
# Residue 33: -1.036 REU
# Residue 34: -2.381 REU
# Residue 35: -2.224 REU
# Residue 36: -2.116 REU
# Residue 37: -4.911 REU
# Residue 38: -4.756 REU
# Residue 39: -1.602 REU
# Residue 40: -3.287 REU
# Residue 41: -4.238 REU
# Residue 42: -1.054 REU
# Residue 43: -6.110 REU
# Residue 44: -3.900 REU
# Residue 45: -2.289 REU
# Residue 46: 1.357 REU
# Residue 47: -1.503 REU
# Residue 48: -2.267 REU
# Residue 49: -1.009 REU
# Residue 50: -5.167 REU
# Residue 51: -3.192 REU
# Residue 52: -3.581 REU
# Residue 53: 0.906 REU
# Residue 54: -2.369 REU
# Residue 55: -3.943 REU
# Residue 56: -6.564 REU
# Residue 57: -1.919 REU
# Residue 58: -3.782 REU
# Residue 59: -4.258 REU
# Residue 60: -2.705 REU
# Residue 61: -5.669 REU
# Residue 62: -2.318 REU
# Residue 63: 1.625 REU
# Residue 64: -0.765 REU
# Residue 65: -2.847 REU
# Residue 66: -1.465 REU
# Residue 67: -7.449 REU
# Residue 68: -1.186 REU
# Residue 69: -5.406 REU
# Residue 70: -2.862 REU
# Residue 71: -4.000 REU
# Residue 72: 1.090 REU
# Residue 73: -1.520 REU
# Residue 74: -1.101 REU
# Residue 75: -1.125 REU
# Residue 76: 0.646 REU
