# %%
import pyrosetta

# Initialize PyRosetta (use default options)
pyrosetta.init()

# Load the PDB file into a pose
pose = pyrosetta.pose_from_pdb(r"/home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb")
print(f"Loaded structure with {pose.total_residue()} residues.")
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python311.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python311.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/bharath-sooryaa-m/anaconda3/envs/praisonai/lib/python3.11/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-864907984 seed_offset=0 real_seed=-864907984
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-864907984 RG_type=mt19937
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 985 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 0.438502 seconds.
# core.import_pose.import_pose: File '/home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb' automatically determined to be of type PDB from contents.
# Loaded structure with 420 residues.

# %%
# Get the default full-atom score function
scorefxn = pyrosetta.get_fa_scorefxn()

# Score the original structure
initial_score = scorefxn(pose)
print(f"Initial Total Score: {initial_score:.3f} REU")
# Out:
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.etable: Starting energy table calculation
# core.scoring.etable: smooth_etable: changing atr/rep split to bottom of energy well
# core.scoring.etable: smooth_etable: spline smoothing lj etables (maxdis = 6)
# core.scoring.etable: smooth_etable: spline smoothing solvation etables (max_dis = 6)
# core.scoring.etable: Finished calculating energy tables.
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/prepro.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA_n
# core.scoring.P_AA: shapovalov_lib::shap_p_aa_pp_smooth_level of 1( aka low_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/shapovalov/10deg/kappa131/a20.prop
# basic.io.database: Database file opened: scoring/score_functions/elec_cp_reps.dat
# core.scoring.elec.util: Read 40 countpair representative atoms
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib_fixes_enable option is true.
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib::shap_dun10_smooth_level of 1( aka lowest_smooth ) got activated.
# core.pack.dunbrack.RotamerLibrary: Binary rotamer library selected: /home/bharath-sooryaa-m/anaconda3/envs/praisonai/lib/python3.11/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin
# core.pack.dunbrack.RotamerLibrary: Using Dunbrack library binary file '/home/bharath-sooryaa-m/anaconda3/envs/praisonai/lib/python3.11/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin'.
# core.pack.dunbrack.RotamerLibrary: Dunbrack 2010 library took 0.153235 seconds to load from binary
# Initial Total Score: 4197.794 REU

# %%
from pyrosetta.rosetta.protocols.relax import FastRelax
from pyrosetta.rosetta.core.pack.task import TaskFactory
from pyrosetta.rosetta.core.pack.task.operation import RestrictToRepacking

# Set up the FastRelax protocol
fast_relax = FastRelax()
fast_relax.set_scorefxn(scorefxn)

# Optionally, you can set additional parameters if needed
# fast_relax.max_iter(200)

# Run the relax protocol on a copy of the pose
import copy
pose_relaxed = pyrosetta.Pose()
pose_relaxed.assign(pose)  # make a copy

fast_relax.apply(pose_relaxed)
print("Relaxation complete.")
# Out:
# protocols.relax.RelaxScriptManager: Reading relax scripts list from database.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# protocols.relax.RelaxScriptManager: Looking for MonomerRelax2019.txt
# protocols.relax.RelaxScriptManager: ================== Reading script file: /home/bharath-sooryaa-m/anaconda3/envs/praisonai/lib/python3.11/site-packages/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.txt ==================
# protocols.relax.RelaxScriptManager: repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 1
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: min 0.00001
# protocols.relax.RelaxScriptManager: accept_to_best
# protocols.relax.RelaxScriptManager: endrepeat
# protocols.relax.FastRelax: CMD: repeat  4197.79  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  4197.79  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  3897.51  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9095 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  2652.83  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  2670.67  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -662.457  48.6846  48.6846  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -662.457  48.6846  48.6846  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  417.002  48.6846  48.6846  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9020 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -190.549  48.6846  48.6846  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.18  48.6846  48.6846  0.154
# protocols.relax.FastRelax: CMD: min  920.257  37.7394  37.7394  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  920.257  37.7394  37.7394  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  2727.99  37.7394  37.7394  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8831 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  2139.85  37.7394  37.7394  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  2259.07  37.7394  37.7394  0.31955
# protocols.relax.FastRelax: CMD: min  5449.88  36.1517  36.1517  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  5449.88  36.1517  36.1517  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  9971.2  36.1517  36.1517  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8504 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  8242.9  36.1517  36.1517  0.55
# protocols.relax.FastRelax: CMD: min  2151.12  46.1481  46.1481  0.55
# protocols.relax.FastRelax: MRP: 0  2151.12  2151.12  46.1481  46.1481
# protocols.relax.FastRelax: CMD: accept_to_best  2151.12  46.1481  46.1481  0.55
# protocols.relax.FastRelax: CMD: endrepeat  2151.12  46.1481  46.1481  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  2151.12  46.1481  46.1481  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -609.975  46.1481  46.1481  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9472 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -743.259  46.1481  46.1481  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -729.481  46.1481  46.1481  0.02805
# protocols.relax.FastRelax: CMD: min  -378.782  39.7488  39.7488  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -378.782  39.7488  39.7488  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  3072.57  39.7488  39.7488  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9708 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  844.051  39.7488  39.7488  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  952.729  39.7488  39.7488  0.154
# protocols.relax.FastRelax: CMD: min  -794.207  41.5471  41.5471  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -794.207  41.5471  41.5471  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -641.003  41.5471  41.5471  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8672 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -657.894  41.5471  41.5471  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -646.059  41.5471  41.5471  0.31955
# protocols.relax.FastRelax: CMD: min  524.78  41.5329  41.5329  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  524.78  41.5329  41.5329  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  1541.24  41.5329  41.5329  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8429 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -36.007  41.5329  41.5329  0.55
# protocols.relax.FastRelax: CMD: min  -613.788  41.2764  41.2764  0.55
# protocols.relax.FastRelax: MRP: 1  -613.788  -613.788  41.2764  41.2764
# protocols.relax.FastRelax: CMD: accept_to_best  -613.788  41.2764  41.2764  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -613.788  41.2764  41.2764  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -613.788  41.2764  41.2764  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  
    """
    Load a protein structure from a PDB file into a PyRosetta pose.
    """
    try:
        pose = pyrosetta.pose_from_pdb(pdb_file)
        print(f"Loaded structure from {pdb_file} with {pose.total_residue()} residues.")
        return pose
    except Exception as e:
        print(f"Error loading PDB file {pdb_file}: {e}")
        return None

def score_protein(pose, scorefxn=None):
    """
    Score the given pose using a full-atom score function.
    If no scorefxn is provided, the default full-atom score function is used.
    Returns the total score (REU).
    """
    if scorefxn is None:
        scorefxn = pyrosetta.get_fa_scorefxn()
    total_score = scorefxn(pose)
    print(f"Total Score: {total_score:.3f} REU")
    return total_score, scorefxn

def relax_structure(pose, scorefxn, nstruct=1):
    """
    Apply the FastRelax protocol to the structure.
    Returns the relaxed pose.
    """
    # Create a copy of the pose to relax
    relaxed_pose = pyrosetta.Pose()
    relaxed_pose.assign(pose)
    
    fast_relax = FastRelax()
    fast_relax.set_scorefxn(scorefxn)
    
    # Apply relaxation nstruct times (for multiple models, if desired)
    for i in range(nstruct):
        fast_relax.apply(relaxed_pose)
    print("Relaxation complete.")
    return relaxed_pose

def print_per_residue_energies(pose):
    """
    Print the per-residue energies for the given pose.
    """
    print("Per-residue energies:")
    # Access the energies from the pose object
    energies = pose.energies()
    for i in range(1, pose.total_residue() + 1):
        energy = energies.residue_total_energy(i)
        print(f"Residue {i}: {energy:.3f} REU")

# -------------------------------
# Example workflow
# -------------------------------
if __name__ == "__main__":
    # Initialize PyRosetta
    initialize_pyrosetta("-ex1 -ex2aro")
    
    # Load protein structure (update path as needed)
    pdb_file = r"/home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb"
    pose = load_protein(pdb_file)
    if pose is None:
        raise SystemExit("Failed to load PDB file.")
    
    # Score the original structure
    initial_score, scorefxn = score_protein(pose)
    
    # Relax the structure
    pose_relaxed = relax_structure(pose, scorefxn)
    
    # Re-score the relaxed structure
    relaxed_score, _ = score_protein(pose_relaxed)
    
    # Print per-residue energies
    print_per_residue_energies(pose_relaxed)
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python311.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python311.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# Residue 400: -0.576 REU
# Residue 401: -2.842 REU
# Residue 402: -5.423 REU
# Residue 403: 3.303 REU
# Residue 404: -0.273 REU
# Residue 405: -1.368 REU
# Residue 406: -1.211 REU
# Residue 407: 0.455 REU
# Residue 408: -2.551 REU
# Residue 409: -0.474 REU
# Residue 410: 6.239 REU
# Residue 411: 3.469 REU
# Residue 412: 1.079 REU
# Residue 413: -2.307 REU
# Residue 414: -0.580 REU
# Residue 415: -1.668 REU
# Residue 416: -3.036 REU
# Residue 417: -1.743 REU
# Residue 418: 2.938 REU
# Residue 419: -0.245 REU
# Residue 420: -1.196 REU

# %%
import pyrosetta
from pyrosetta.rosetta.protocols.relax import FastRelax

class PyRosettaWrapper:
    dir = ""
    def __init__(self, dir):
        """
        Initialize the PyRosettaWrapper with the directory for PDB files.
        """
        self.dir = dir
        print(f"PyRosettaWrapper initialized with directory: {self.dir}")
    
    def initialize_pyrosetta(self,extra_flags=""):
        """
        Initialize PyRosetta with optional extra flags.
        """
        pyrosetta.init(extra_flags)
        print("PyRosetta initialized.")

    def load_protein(self,pdb_id):
        """
        Load a protein structure from a PDB file into a PyRosetta pose.
        """
        try:
            pose = pyrosetta.pose_from_pdb(pdb_id)
            print(f"Loaded structure from {pdb_id} with {pose.total_residue()} residues.")
            return pose
        except Exception as e:
            print(f"Error loading PDB file {pdb_id}: {e}")
            return None

    def score_protein(self,pose, scorefxn=None):
        """
        Score the given pose using a full-atom score function.
        If no scorefxn is provided, the default full-atom score function is used.
        Returns the total score (REU).
        """
        if scorefxn is None:
            scorefxn = pyrosetta.get_fa_scorefxn()
        total_score = scorefxn(pose)
        print(f"Total Score: {total_score:.3f} REU")
        return total_score, scorefxn

    def relax_structure(self, pose, scorefxn, nstruct=1, output_pdb="relaxed_structure.pdb"):
        """
        Apply the FastRelax protocol to the structure and save the relaxed pose to a PDB file.
        Returns the relaxed pose.
        """
        # Create a copy of the pose to relax
        relaxed_pose = pyrosetta.Pose()
        relaxed_pose.assign(pose)
        
        fast_relax = FastRelax()
        fast_relax.set_scorefxn(scorefxn)
        
        # Apply relaxation nstruct times (for multiple models, if desired)
        for i in range(nstruct):
            fast_relax.apply(relaxed_pose)
        
        # Save the relaxed pose to a PDB file
        relaxed_pose.dump_pdb(output_pdb)
        print(f"Relaxed structure saved to {output_pdb}.")
        
        print("Relaxation complete.")
        return relaxed_pose

    def print_per_residue_energies(self,pose):
        """
        Print the per-residue energies for the given pose.
        """
        print("Per-residue energies:")
        # Access the energies from the pose object
        energies = pose.energies()
        for i in range(1, pose.total_residue() + 1):
            energy = energies.residue_total_energy(i)
            print(f"Residue {i}: {energy:.3f} REU")
    
    def run(self,pdb_file):
            # Initialize PyRosetta
        initialize_pyrosetta("-ex1 -ex2aro")
        
        # Load protein structure (update path as needed)
        pose = self.load_protein(pdb_file)
        if pose is None:
            raise SystemExit("Failed to load PDB file.")
        
        # Score the original structure
        initial_score, scorefxn = self.score_protein(pose)
        
        # Relax the structure
        pose_relaxed = self.relax_structure(pose, scorefxn)
        
        # Re-score the relaxed structure
        relaxed_score, _ = self.score_protein(pose_relaxed)
        
        # Print per-residue energies
        self.print_per_residue_energies(pose_relaxed)

# %%
wrap = PyRosettaWrapper()
pdb_file = r"/home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb"
wrap.run(pdb_file)
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python311.ubuntu 2025.13+release.80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b 2025-03-27T08:32:50] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python311.ubuntu r396 2025.13+release.80dd00bc09 80dd00bc09d2543ce4b9a50f13c49219ee5cdd3b http://www.pyrosetta.org 2025-03-27T08:32:50
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/bharath-sooryaa-m/anaconda3/envs/praisonai/lib/python3.11/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=673568859 seed_offset=0 real_seed=673568859
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=673568859 RG_type=mt19937
# PyRosetta initialized.
# core.import_pose.import_pose: File '/home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb' automatically determined to be of type PDB from contents.
# Loaded structure from /home/bharath-sooryaa-m/Documents/BIO/proj/Protein-Designing-With-Agents/cache/session_20250407-102257_c66acf1a/pdb/O00712.pdb with 420 residues.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Total Score: 4197.794 REU
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# protocols.relax.FastRelax: CMD: repeat  4197.79  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  4197.79  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  3897.51  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9095 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  2653.04  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  2669.87  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -57.9256  47.4948  47.4948  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -57.9256  47.4948  47.4948  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  3579.95  47.4948  47.4948  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8921 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  1859.76  47.4948  47.4948  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  2015.42  47.4948  47.4948  0.154
# protocols.relax.FastRelax: CMD: min  10575.3  38.3639  38.3639  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  10575.3  38.3639  38.3639  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  22140.5  38.3639  38.3639  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8712 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  16553  38.3639  38.3639  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  17241.7  38.3639  38.3639  0.31955
# protocols.relax.FastRelax: CMD: min  12206.1  45.608  45.608  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  12206.1  45.608  45.608  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  21436.6  45.608  45.608  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 6966 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack
0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -574.592  40.6133  40.6133  0.31955
# protocols.relax.FastRelax: CMD: min  -604  40.422  40.422  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -604  40.422  40.422  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -479.113  40.422  40.422  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7413 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -479.929  40.422  40.422  0.55
# protocols.relax.FastRelax: CMD: min  -523.169  40.8228  40.8228  0.55
# protocols.relax.FastRelax: MRP: 3  -523.169  -523.169  40.8228  40.8228
# protocols.relax.FastRelax: CMD: accept_to_best  -523.169  40.8228  40.8228  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -523.169  40.8228  40.8228  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -523.169  40.8228  40.8228  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -714.473  40.8228  40.8228  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8203 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -741.035  40.8228  40.8228  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -734.427  40.8228  40.8228  0.02805
# protocols.relax.FastRelax: CMD: min  -910.385  40.086  40.086  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -910.385  40.086  40.086  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -527.485  40.086  40.086  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8227 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -558.232  40.086  40.086  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -535.802  40.086  40.086  0.154
# protocols.relax.FastRelax: CMD: min  -723.301  38.3248  38.3248  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -723.301  38.3248  38.3248  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -592.357  38.3248  38.3248  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7561 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -593.892  38.3248  38.3248  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -583.688  38.3248  38.3248  0.31955
# protocols.relax.FastRelax: CMD: min  -620.4  38.6803  38.6803  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -620.4  38.6803  38.6803  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -496.224  38.6803  38.6803  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7390 rotamers at 420 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -496.145  38.6803  38.6803  0.55
# protocols.relax.FastRelax: CMD: min  -542.789  38.5091  38.5091  0.55
# protocols.relax.FastRelax: MRP: 4  -542.789  -542.789  38.5091  38.5091
# protocols.relax.FastRelax: CMD: accept_to_best  -542.789  38.5091  38.5091  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -542.789  38.5091  38.5091  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# Relaxed structure saved to relaxed_structure.pdb.
# Relaxation complete.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Total Score: -542.789 REU
# Per-residue energies:
# Residue 1: 1.015 REU
# Residue 2: 0.957 REU
# Residue 3: -2.014 REU
# Residue 4: -1.125 REU
# Residue 5: -2.947 REU
# Residue 6: 1.275 REU
# Residue 7: -0.273 REU
# Residue 8: 0.041 REU
# Residue 9: -2.760 REU
# Residue 10: 0.144 REU
# Residue 11: -1.692 REU
# Residue 12: -2.599 REU
# Residue 13: -0.281 REU
# Residue 14: -2.186 REU
# Residue 15: -3.555 REU
# Residue 16: -1.382 REU
# Residue 17: -4.589 REU
# Residue 18: -1.001 REU
