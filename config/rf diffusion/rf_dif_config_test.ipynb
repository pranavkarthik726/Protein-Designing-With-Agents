# %%
import os
from crewai import Agent, Task, Crew,LLM
from crewai_tools import tools
from langchain_community.tools import DuckDuckGoSearchRun

# %%
os.environ["GEMINI_API_KEY"] = "AIzaSyAtKcMCcEwHQqL01NGIA6fh0V9WEtSGnF4"  
llm = LLM(
    model="gemini-2.0-flash-exp",
    temperature=0.7
)

# %%
from crewai.tools import tool
@tool("DuckDuckGoSearch")
def search_tool(search_query: str) -> str:
    """Search DuckDuckGo for a given topic and return the results."""
    return DuckDuckGoSearchRun().run(search_query)

# %%
Researcher = Agent(
    role='Protein Scaffold Information Retriever',
    goal='Extract relevant information about protein scaffolds from the specified Wikipedia page',
    backstory='An expert in navigating scientific resources, specializing in molecular biology and protein functions.',
    tools=[],
    llm=llm,
    verbose=True
)

Configuration = Agent(
    role='Protein Scaffold Report Writer',
    goal='Synthesize retrieved information into a coherent and informative report on protein scaffolds',
    backstory='A skilled scientific writer adept at communicating complex biological concepts clearly.',
    llm=llm,
    verbose=True
)


retrieve = Task(
    description='Using the WebsiteSearchTool, retrieve key information about protein scaffolds from the Wikipedia page at https://en.wikipedia.org/wiki/Scaffold_protein. Focus on extracting details about their definition, functions in signaling pathways, examples of scaffold proteins, and their roles in cellular processes.',
    expected_output='A collection of relevant excerpts or summaries from the Wikipedia page covering the definition, functions, examples, and mechanisms of protein scaffolds.',
    agent=retrieveResearchr
)

# Define the Write Task
write = Task(
    description='Based on the information retrieved by the Protein Scaffold Information Retriever, write a comprehensive report on protein scaffolds. Organize the report into sections such as Introduction, Functions, Examples, and Conclusion. Ensure the content is accurate, informative, and accessible to readers with a basic understanding of biology.',
    expected_output='A markdown-formatted report with at least four sections, providing a detailed overview of protein scaffolds, their importance in cellular signaling, and specific examples.',
    agent=writer,
    output_file='protein_scaffold_report.md'
)

# Assemble the Crew
crew = Crew(
    agents=[retriever, writer],
    tasks=[retrieve, write],
    verbose=True,  # Enable planning for task coordination
)

# Execute the Tasks
crew.kickoff()
# Out:
# 2025-03-09 17:02:36,329 - 12608 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# 2025-03-09 17:02:36,492 - 12608 - _metadata.py-_metadata:142 - WARNING: Compute Engine Metadata server unavailable on attempt 1 of 3. Reason: [WinError 10051] A socket operation was attempted to an unreachable network
# LLM value is already an LLM object
# LLM value is already an LLM object
# # Agent: Protein Scaffold Information Retriever
# ## Task: Using the WebsiteSearchTool, retrieve key information about protein scaffolds from the Wikipedia page at https://en.wikipedia.org/wiki/Scaffold_protein. Focus on extracting details about their definition, functions in signaling pathways, examples of scaffold proteins, and their roles in cellular processes.
# ...
